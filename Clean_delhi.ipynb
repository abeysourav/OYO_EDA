# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import requests
from bs4 import BeautifulSoup

import re
import time

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
import os

# %%
d1=pd.read_csv('D:\\oyo_delhi.csv')
d1.head()
# Out:
#    Unnamed: 0                   Hotel Name  \
# 0           0            OYO 28715 Acclaim
# 1           1  Capital O 88089 Hotel Elite
# 2           2         OYO 87715 Comfort In
# 3           3         OYO 87875 Krazy Home
# 4           4        OYO 22355 Hotel Istay
#
#                                       Cost Per Night  \
# 0  ₹500₹196374% offper room per nightView Details...
# 1  ₹549₹254778% offper room per nightView Details...
# 2  ₹541₹202573% offper room per nightView Details...
# 3  ₹500₹192574% offper room per nightView Details...
# 4  ₹699₹237170% offper room per nightView Details...
#
#                         Rating  \
# 0    4.5 (6 Ratings)·Excellent
# 1   4.5 (74 Ratings)·Excellent
# 2  4.6 (136 Ratings)·Excellent
# 3   4.5 (15 Ratings)·Excellent
# 4  4.6 (176 Ratings)·Excellent
#
#                                             Features  \
# 0        Hair Dryer  Reception  Free Wifi  + 15 more
# 1   Parking Facility  Reception  Free Wifi  + 14 ...
# ...

# %%
d1.shape
# Out:
# (180, 6)

# %%
print(f"Data has {d1.shape[0]} Rows and {d1.shape[1]} Coloumns")
# Out:
# Data has 180 Rows and 6 Coloumns

# %%
d1.columns
# Out:
# Index(['Unnamed: 0', 'Hotel Name', 'Cost Per Night', 'Rating', 'Features',
#        'Location'],
#       dtype='object')

# %%
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      180 non-null    int64
#  1   Hotel Name      180 non-null    object
#  2   Cost Per Night  180 non-null    object
#  3   Rating          180 non-null    object
#  4   Features        180 non-null    object
#  5   Location        180 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 8.6+ KB

# %%
d1.isnull().sum()
# Out:
# Unnamed: 0        0
# Hotel Name        0
# Cost Per Night    0
# Rating            0
# Features          0
# Location          0
# dtype: int64

# %%
d1['Cost Per Night']
# Out:
# 0      ₹500₹196374% offper room per nightView Details...
# 1      ₹549₹254778% offper room per nightView Details...
# 2      ₹541₹202573% offper room per nightView Details...
# 3      ₹500₹192574% offper room per nightView Details...
# 4      ₹699₹237170% offper room per nightView Details...
#                              ...
# 175    ₹899₹288268% offper room per nightView Details...
# 176    ₹625₹222971% offper room per nightView Details...
# 177    ₹1684₹320747% offper room per nightView Detail...
# 178    ₹747₹225366% offper room per nightView Details...
# 179    ₹1014₹193147% offper room per nightView Detail...
# Name: Cost Per Night, Length: 180, dtype: object

# %%
d1['Cost Per Night'][0]
# Out:
# '₹500₹196374% offper room per nightView DetailsBook Now'

# %%
re.findall(r"₹[0-9]+₹",d1['Cost Per Night'][0])
# Out:
# ['₹500₹']

# %%
#re.findall(r"₹[0-9]+",d1['Cost Per Night'][0])

# %%
z = []
for x in d1['Cost Per Night']:
    z.append(re.findall("₹[0-9]+₹",x)[0])
print(z)
# Out:
# ['₹500₹', '₹549₹', '₹541₹', '₹500₹', '₹699₹', '₹778₹', '₹799₹', '₹500₹', '₹695₹', '₹509₹', '₹868₹', '₹811₹', '₹899₹', '₹799₹', '₹549₹', '₹364₹', '₹541₹', '₹433₹', '₹541₹', '₹974₹', '₹799₹', '₹454₹', '₹899₹', '₹949₹', '₹500₹', '₹576₹', '₹1216₹', '₹722₹', '₹376₹', '₹625₹', '₹925₹', '₹657₹', '₹559₹', '₹625₹', '₹799₹', '₹1279₹', '₹550₹', '₹799₹', '₹664₹', '₹625₹', '₹549₹', '₹684₹', '₹625₹', '₹541₹', '₹830₹', '₹541₹', '₹901₹', '₹766₹', '₹1318₹', '₹641₹', '₹625₹', '₹821₹', '₹500₹', '₹489₹', '₹625₹', '₹1902₹', '₹747₹', '₹598₹', '₹699₹', '₹500₹', '₹645₹', '₹1300₹', '₹625₹', '₹1216₹', '₹821₹', '₹652₹', '₹664₹', '₹565₹', '₹1014₹', '₹747₹', '₹695₹', '₹949₹', '₹1216₹', '₹541₹', '₹1014₹', '₹699₹', '₹365₹', '₹695₹', '₹1546₹', '₹1014₹', '₹514₹', '₹1478₹', '₹565₹', '₹664₹', '₹740₹', '₹500₹', '₹713₹', '₹775₹', '₹868₹', '₹500₹', '₹791₹', '₹759₹', '₹1247₹', '₹541₹', '₹1261₹', '₹799₹', '₹549₹', '₹713₹', '₹1014₹', '₹899₹', '₹636₹', '₹1372₹', '₹807₹', '₹565₹', '₹514₹', '₹1612₹', '₹1216₹', '₹541₹', '₹808₹'
# ...

# %%
for x in z:
    print(x.replace("₹",""))
# Out:
# 500
# 549
# 541
# 500
# 699
# 778
# 799
# 500
# 695
# 509
# 868
# 811
# 899
# 799
# 549
# 364
# 541
# 433
# 541
# 974
# 799
# 454
# 899
# 949
# 500
# 576
# 1216
# 722
# 376
# 625
# 925
# 657
# 559
# 625
# 799
# 1279
# 550
# 799
# 664
# 625
# 549
# 684
# 625
# 541
# 830
# 541
# 901
# 766
# 1318
# 641
# 625
# 821
# 500
# 489
# 625
# 1902
# 747
# 598
# 699
# 500
# 645
# 1300
# 625
# 1216
# 821
# 652
# 664
# 565
# 1014
# 747
# 695
# 949
# 1216
# 541
# 1014
# 699
# 365
# 695
# 1546
# 1014
# 514
# 1478
# 565
# 664
# 740
# 500
# 713
# 775
# 868
# 500
# 791
# 759
# 1247
# 541
# 1261
# 799
# 549
# 713
# 1014
# 899
# 636
# 1372
# 807
# 565
# 514
# 1612
# 1216
# 541
# 808
# 1000
# 625
# 811
# 994
# 899
# 985
# 715
# 1340
# 1014
# 715
# 541
# 994
# 1482
# 541
# 1014
# 961
# 647
# 499
# 541
# 562
# 811
# 592
# 657
# 792
# 1318
# 1807
# 691
# 783
# 546
# 1786
# 713
# 949
# 699
# 910
# 696
# 920
# 899
# 747
# 899
# 695
# 688
# 675
# 1335
# 699
# 576
# 500
# 921
# 1420
# 625
# 625
# 949
# 821
# 517
# ...

# %%
d1['Selling_Price']=d1['Cost Per Night'].apply(lambda x: float(re.findall("₹[0-9]+₹",x)[0].replace('₹','')))

# %%
d1.head()
# Out:
#    Unnamed: 0                   Hotel Name  \
# 0           0            OYO 28715 Acclaim
# 1           1  Capital O 88089 Hotel Elite
# 2           2         OYO 87715 Comfort In
# 3           3         OYO 87875 Krazy Home
# 4           4        OYO 22355 Hotel Istay
#
#                                       Cost Per Night  \
# 0  ₹500₹196374% offper room per nightView Details...
# 1  ₹549₹254778% offper room per nightView Details...
# 2  ₹541₹202573% offper room per nightView Details...
# 3  ₹500₹192574% offper room per nightView Details...
# 4  ₹699₹237170% offper room per nightView Details...
#
#                         Rating  \
# 0    4.5 (6 Ratings)·Excellent
# 1   4.5 (74 Ratings)·Excellent
# 2  4.6 (136 Ratings)·Excellent
# 3   4.5 (15 Ratings)·Excellent
# 4  4.6 (176 Ratings)·Excellent
#
#                                             Features  \
# 0        Hair Dryer  Reception  Free Wifi  + 15 more
# 1   Parking Facility  Reception  Free Wifi  + 14 ...
# ...

# %%
d1['Cost Per Night']
# Out:
# 0      ₹500₹196374% offper room per nightView Details...
# 1      ₹549₹254778% offper room per nightView Details...
# 2      ₹541₹202573% offper room per nightView Details...
# 3      ₹500₹192574% offper room per nightView Details...
# 4      ₹699₹237170% offper room per nightView Details...
#                              ...
# 175    ₹899₹288268% offper room per nightView Details...
# 176    ₹625₹222971% offper room per nightView Details...
# 177    ₹1684₹320747% offper room per nightView Detail...
# 178    ₹747₹225366% offper room per nightView Details...
# 179    ₹1014₹193147% offper room per nightView Detail...
# Name: Cost Per Night, Length: 180, dtype: object

# %%
d1['Cost Per Night'][0]
# Out:
# '₹500₹196374% offper room per nightView DetailsBook Now'

# %%
re.findall(r"₹\d{4}",d1['Cost Per Night'][0])
# Out:
# ['₹1963']

# %%
d1['Cost_Price']=d1['Cost Per Night'].apply(lambda x: float(re.findall(r"₹\d{4}",x)[0].replace('₹','')))

# %%
d1.head()
# Out:
#    Unnamed: 0                   Hotel Name  \
# 0           0            OYO 28715 Acclaim
# 1           1  Capital O 88089 Hotel Elite
# 2           2         OYO 87715 Comfort In
# 3           3         OYO 87875 Krazy Home
# 4           4        OYO 22355 Hotel Istay
#
#                                       Cost Per Night  \
# 0  ₹500₹196374% offper room per nightView Details...
# 1  ₹549₹254778% offper room per nightView Details...
# 2  ₹541₹202573% offper room per nightView Details...
# 3  ₹500₹192574% offper room per nightView Details...
# 4  ₹699₹237170% offper room per nightView Details...
#
#                         Rating  \
# 0    4.5 (6 Ratings)·Excellent
# 1   4.5 (74 Ratings)·Excellent
# 2  4.6 (136 Ratings)·Excellent
# 3   4.5 (15 Ratings)·Excellent
# 4  4.6 (176 Ratings)·Excellent
#
#                                             Features  \
# 0        Hair Dryer  Reception  Free Wifi  + 15 more
# 1   Parking Facility  Reception  Free Wifi  + 14 ...
# ...

# %%
d1['Cost Per Night'][0]
# Out:
# '₹500₹196374% offper room per nightView DetailsBook Now'

# %%
re.findall(r"(\w\w)%",d1['Cost Per Night'][0])
# Out:
# ['74']

# %%
d1['Discount']=d1['Cost Per Night'].apply(lambda x: float(re.findall(r"(\w\w)%",x)[0]))

# %%
d1.head()
# Out:
#    Unnamed: 0                   Hotel Name  \
# 0           0            OYO 28715 Acclaim
# 1           1  Capital O 88089 Hotel Elite
# 2           2         OYO 87715 Comfort In
# 3           3         OYO 87875 Krazy Home
# 4           4        OYO 22355 Hotel Istay
#
#                                       Cost Per Night  \
# 0  ₹500₹196374% offper room per nightView Details...
# 1  ₹549₹254778% offper room per nightView Details...
# 2  ₹541₹202573% offper room per nightView Details...
# 3  ₹500₹192574% offper room per nightView Details...
# 4  ₹699₹237170% offper room per nightView Details...
#
#                         Rating  \
# 0    4.5 (6 Ratings)·Excellent
# 1   4.5 (74 Ratings)·Excellent
# 2  4.6 (136 Ratings)·Excellent
# 3   4.5 (15 Ratings)·Excellent
# 4  4.6 (176 Ratings)·Excellent
#
#                                             Features  \
# 0        Hair Dryer  Reception  Free Wifi  + 15 more
# 1   Parking Facility  Reception  Free Wifi  + 14 ...
# ...

# %%
d1['City'] = 'Delhi'

# %%
d1
# Out:
#      Unnamed: 0                          Hotel Name  \
# 0             0                   OYO 28715 Acclaim
# 1             1         Capital O 88089 Hotel Elite
# 2             2                OYO 87715 Comfort In
# 3             3                OYO 87875 Krazy Home
# 4             4               OYO 22355 Hotel Istay
# ..          ...                                 ...
# 175         175         OYO 27979 Krishna Residency
# 176         176               OYO 85494 Osho Palace
# 177         177  Collection O 9266 Hotel Kapoor Inn
# 178         178        OYO 22354 PG Hospitality Inn
# 179         179    Collection O 85116 peaceful stay
#
#                                         Cost Per Night  \
# 0    ₹500₹196374% offper room per nightView Details...
# 1    ₹549₹254778% offper room per nightView Details...
# 2    ₹541₹202573% offper room per nightView Details...
# 3    ₹500₹192574% offper room per nightView Details...
# 4    ₹699₹237170% offper room per nightView Details...
# ...

# %%
d1['Locality']=d1['Location'].apply(lambda x:x.replace('Delhi',''))

# %%
d1.head()
# Out:
#    Unnamed: 0                   Hotel Name  \
# 0           0            OYO 28715 Acclaim
# 1           1  Capital O 88089 Hotel Elite
# 2           2         OYO 87715 Comfort In
# 3           3         OYO 87875 Krazy Home
# 4           4        OYO 22355 Hotel Istay
#
#                                       Cost Per Night  \
# 0  ₹500₹196374% offper room per nightView Details...
# 1  ₹549₹254778% offper room per nightView Details...
# 2  ₹541₹202573% offper room per nightView Details...
# 3  ₹500₹192574% offper room per nightView Details...
# 4  ₹699₹237170% offper room per nightView Details...
#
#                         Rating  \
# 0    4.5 (6 Ratings)·Excellent
# 1   4.5 (74 Ratings)·Excellent
# 2  4.6 (136 Ratings)·Excellent
# 3   4.5 (15 Ratings)·Excellent
# 4  4.6 (176 Ratings)·Excellent
#
#                                             Features  \
# 0        Hair Dryer  Reception  Free Wifi  + 15 more
# 1   Parking Facility  Reception  Free Wifi  + 14 ...
# ...

# %%
d1['Rating'][0]
# Out:
# '4.5 (6 Ratings)·Excellent'

# %%
re.findall(r"\d[.]\d",d1['Rating'][0])
# Out:
# ['4.5']

# %%
Rates=[]
for i in d1['Rating']:
    if len(re.findall(r"\d[.]\d",i))<1:
        Rates.append(np.nan)
    else:
        Rates.append(re.findall(r"\d[.]\d",i)[0])

# %%
Rates
# Out:
# ['4.5',
#  '4.5',
#  '4.6',
#  '4.5',
#  '4.6',
#  '4.8',
#  '4.6',
#  '4.5',
#  '4.6',
#  '4.4',
#  '4.8',
#  '4.6',
#  '4.8',
#  '4.6',
#  '4.7',
#  '2.9',
#  '4.5',
#  '4.3',
#  '4.1',
#  '4.6',
#  '4.5',
#  nan,
#  '4.7',
#  '3.0',
#  '4.0',
#  '3.7',
#  '4.5',
#  '4.4',
#  '3.1',
#  '4.3',
#  '4.3',
#  '2.7',
#  '4.5',
#  '4.4',
#  '4.5',
#  '4.5',
#  '3.3',
#  '4.6',
#  '4.3',
#  '3.4',
#  '4.1',
#  '4.5',
#  '4.4',
#  '3.8',
#  '4.7',
#  '3.1',
#  '4.9',
#  '4.6',
#  '3.5',
#  '4.0',
#  '2.7',
#  nan,
#  '3.7',
#  nan,
#  '3.3',
#  '4.1',
#  '3.9',
#  '3.9',
#  '3.5',
#  '3.8',
#  '4.1',
#  '4.9',
#  '4.1',
#  nan,
#  '4.5',
#  '3.2',
#  '4.2',
#  '2.7',
#  '4.6',
#  '3.7',
#  '4.4',
#  '4.3',
#  '4.5',
#  '2.6',
#  '4.5',
#  '4.7',
#  '3.3',
#  '3.9',
#  '4.7',
#  '4.5',
#  '3.3',
#  '4.8',
#  '3.1',
#  '4.3',
#  '3.5',
#  '2.8',
#  '4.2',
#  '3.2',
#  '4.7',
#  '1.6',
#  '4.6',
#  '2.4',
#  '4.7',
#  '3.3',
#  '3.8',
#  '3.9',
#  '3.4',
#  '3.7',
#  '4.5',
#  '4.4',
# ...

# %%
d1['Rate']=Rates

# %%
d1.head()
# Out:
#    Unnamed: 0                   Hotel Name  \
# 0           0            OYO 28715 Acclaim
# 1           1  Capital O 88089 Hotel Elite
# 2           2         OYO 87715 Comfort In
# 3           3         OYO 87875 Krazy Home
# 4           4        OYO 22355 Hotel Istay
#
#                                       Cost Per Night  \
# 0  ₹500₹196374% offper room per nightView Details...
# 1  ₹549₹254778% offper room per nightView Details...
# 2  ₹541₹202573% offper room per nightView Details...
# 3  ₹500₹192574% offper room per nightView Details...
# 4  ₹699₹237170% offper room per nightView Details...
#
#                         Rating  \
# 0    4.5 (6 Ratings)·Excellent
# 1   4.5 (74 Ratings)·Excellent
# 2  4.6 (136 Ratings)·Excellent
# 3   4.5 (15 Ratings)·Excellent
# 4  4.6 (176 Ratings)·Excellent
#
#                                             Features  \
# 0        Hair Dryer  Reception  Free Wifi  + 15 more
# 1   Parking Facility  Reception  Free Wifi  + 14 ...
# ...

# %%
d1['Rating'][0]
# Out:
# '4.5 (6 Ratings)·Excellent'

# %%
re.findall(r"\d\s[A-z]+",d1['Rating'][0])
# Out:
# ['6 Ratings']

# %%
rate_num=[]
for i in d1['Rating']:
    if len(re.findall(r"\d\s[A-z]+",i))<1:
        rate_num.append(np.nan)
    else:
        rate_num.append(re.findall(r"\d\s[A-z]+",i)[0])

# %%
d1['Customer_Rating']=rate_num

# %%
d1.head()
# Out:
#    Unnamed: 0                   Hotel Name  \
# 0           0            OYO 28715 Acclaim
# 1           1  Capital O 88089 Hotel Elite
# 2           2         OYO 87715 Comfort In
# 3           3         OYO 87875 Krazy Home
# 4           4        OYO 22355 Hotel Istay
#
#                                       Cost Per Night  \
# 0  ₹500₹196374% offper room per nightView Details...
# 1  ₹549₹254778% offper room per nightView Details...
# 2  ₹541₹202573% offper room per nightView Details...
# 3  ₹500₹192574% offper room per nightView Details...
# 4  ₹699₹237170% offper room per nightView Details...
#
#                         Rating  \
# 0    4.5 (6 Ratings)·Excellent
# 1   4.5 (74 Ratings)·Excellent
# 2  4.6 (136 Ratings)·Excellent
# 3   4.5 (15 Ratings)·Excellent
# 4  4.6 (176 Ratings)·Excellent
#
#                                             Features  \
# 0        Hair Dryer  Reception  Free Wifi  + 15 more
# 1   Parking Facility  Reception  Free Wifi  + 14 ...
# ...

# %%
d1['Rating'][0]
# Out:
# '4.5 (6 Ratings)·Excellent'

# %%
re.findall(r"·([A-z]+)",d1['Rating'][0])
# Out:
# ['Excellent']

# %%
Feedback=[]
for i in d1['Rating']:
    if len(re.findall(r"·([A-z]+)",i))<1:
        Feedback.append(np.nan)
    else:
        Feedback.append(re.findall(r"·([A-z]+)",i)[0])

# %%
d1['Remarks']=Feedback

# %%
d1.head()
# Out:
#    Unnamed: 0                   Hotel Name  \
# 0           0            OYO 28715 Acclaim
# 1           1  Capital O 88089 Hotel Elite
# 2           2         OYO 87715 Comfort In
# 3           3         OYO 87875 Krazy Home
# 4           4        OYO 22355 Hotel Istay
#
#                                       Cost Per Night  \
# 0  ₹500₹196374% offper room per nightView Details...
# 1  ₹549₹254778% offper room per nightView Details...
# 2  ₹541₹202573% offper room per nightView Details...
# 3  ₹500₹192574% offper room per nightView Details...
# 4  ₹699₹237170% offper room per nightView Details...
#
#                         Rating  \
# 0    4.5 (6 Ratings)·Excellent
# 1   4.5 (74 Ratings)·Excellent
# 2  4.6 (136 Ratings)·Excellent
# 3   4.5 (15 Ratings)·Excellent
# 4  4.6 (176 Ratings)·Excellent
#
#                                             Features  \
# 0        Hair Dryer  Reception  Free Wifi  + 15 more
# 1   Parking Facility  Reception  Free Wifi  + 14 ...
# ...

# %%
d1['Hotel Name'][0]
# Out:
# 'OYO 28715 Acclaim'

# %%
d1['Hotel Name']
# Out:
# 0                       OYO 28715 Acclaim
# 1             Capital O 88089 Hotel Elite
# 2                    OYO 87715 Comfort In
# 3                    OYO 87875 Krazy Home
# 4                   OYO 22355 Hotel Istay
#                       ...
# 175           OYO 27979 Krishna Residency
# 176                 OYO 85494 Osho Palace
# 177    Collection O 9266 Hotel Kapoor Inn
# 178          OYO 22354 PG Hospitality Inn
# 179      Collection O 85116 peaceful stay
# Name: Hotel Name, Length: 180, dtype: object

# %%
d1['Hotel Name'].describe()
# Out:
# count                   180
# unique                  180
# top       OYO 28715 Acclaim
# freq                      1
# Name: Hotel Name, dtype: object

# %%
d1['Hotel Name'][0].split()
# Out:
# ['OYO', '28715', 'Acclaim']

# %%
for x in d1['Hotel Name']:
    print(x)
# Out:
# OYO 28715 Acclaim
# Capital O 88089 Hotel Elite
# OYO 87715 Comfort In
# OYO 87875 Krazy Home
# OYO 22355 Hotel Istay
# OYO 70216 Bluemoon Inn
# OYO 70893 Kl Khari Inn
# OYO 86940 Sunrise Villa
# OYO 13277 Hotel Neelam Palace
# OYO 87920 Hotel Happy Stay Inn
# OYO 84391 Townhouse Hotel Grand
# OYO 77554 Red Carmine Deluxe
# Capital O 87150 The imperial orbit
# Collection O 83904 Hotel Small Town
# OYO 75351 Hotel Moon Palace Dx
# SPOT ON 72997 D C Palace
# OYO 87588 Dolphin
# SPOT ON 29024 Jageer Palace
# OYO 86628 Ojas Palace
# OYO 44260 Saffron Inn
# OYO 84351 Welcome Palace
# SPOT ON 83214 Raj Guest House
# Townhouse 483 Hotel Rivasa Regency
# Collection O 76614 J K Hotel
# OYO 86920 Bella House
# Collection O 81401 Sai Residency
# OYO 61891 Hotel Kabila
# Collection O 83921 The Maharaja Grand
# SPOT ON 76979 Chandu Inn
# OYO 87205 Hotel Sapan Plaza
# Collection O 83547 Iconic Residency
# Capital O 86072 Holiday Home
# Collection O 50329 Singh Guest House
# ...

# %%
pro_line=[]
for x in d1['Hotel Name']:
    if len(re.findall(r"OYO|Collection O|OYO Flagship|Townhouse|Capital O|SPOT ON|OYO HOME",x)):
        b=re.findall(r"OYO|Collection O|OYO Flagship|Townhouse|Capital O|SPOT ON|OYO HOME",x)[0]
        pro_line.append(b)
    else:
        pro_line.append(np.NaN)

# %%
pro_line
# Out:
# ['OYO',
#  'Capital O',
#  'OYO',
#  'OYO',
#  'OYO',
#  'OYO',
#  'OYO',
#  'OYO',
#  'OYO',
#  'OYO',
#  'OYO',
#  'OYO',
#  'Capital O',
#  'Collection O',
#  'OYO',
#  'SPOT ON',
#  'OYO',
#  'SPOT ON',
#  'OYO',
#  'OYO',
#  'OYO',
#  'SPOT ON',
#  'Townhouse',
#  'Collection O',
#  'OYO',
#  'Collection O',
#  'OYO',
#  'Collection O',
#  'SPOT ON',
#  'OYO',
#  'Collection O',
#  'Capital O',
#  'Collection O',
#  'OYO',
#  'OYO',
#  'OYO',
#  'OYO',
#  'OYO',
#  'Collection O',
#  'OYO',
#  'OYO',
#  'OYO',
#  'OYO',
#  'OYO',
#  'OYO',
#  'OYO',
#  'OYO',
#  'SPOT ON',
#  'OYO',
#  'OYO',
#  'OYO',
#  'OYO',
#  'OYO',
#  'OYO',
#  'OYO',
#  'Capital O',
#  'Capital O',
#  'Capital O',
#  'OYO',
#  'OYO',
#  'OYO',
#  'OYO',
#  'OYO',
#  'Townhouse',
#  'OYO',
#  'OYO',
#  'Collection O',
#  'OYO',
#  'OYO',
#  'Capital O',
#  'OYO',
#  'OYO',
#  'OYO',
#  'OYO',
#  'OYO',
#  'OYO',
#  'SPOT ON',
#  'OYO',
#  nan,
#  'Capital O',
#  'OYO',
#  'OYO',
#  'OYO',
# ...

# %%
d1['Category']=pro_line

# %%
d1.head()
# Out:
#    Unnamed: 0                   Hotel Name  \
# 0           0            OYO 28715 Acclaim
# 1           1  Capital O 88089 Hotel Elite
# 2           2         OYO 87715 Comfort In
# 3           3         OYO 87875 Krazy Home
# 4           4        OYO 22355 Hotel Istay
#
#                                       Cost Per Night  \
# 0  ₹500₹196374% offper room per nightView Details...
# 1  ₹549₹254778% offper room per nightView Details...
# 2  ₹541₹202573% offper room per nightView Details...
# 3  ₹500₹192574% offper room per nightView Details...
# 4  ₹699₹237170% offper room per nightView Details...
#
#                         Rating  \
# 0    4.5 (6 Ratings)·Excellent
# 1   4.5 (74 Ratings)·Excellent
# 2  4.6 (136 Ratings)·Excellent
# 3   4.5 (15 Ratings)·Excellent
# 4  4.6 (176 Ratings)·Excellent
#
#                                             Features  \
# 0        Hair Dryer  Reception  Free Wifi  + 15 more
# 1   Parking Facility  Reception  Free Wifi  + 14 ...
# ...

# %%
d1['wifi_availabilty'] = d1['Features'].apply(lambda x: 'yes' if 'Free Wifi' in x else 'no')

# %%
d1.head()
# Out:
#    Unnamed: 0                   Hotel Name  \
# 0           0            OYO 28715 Acclaim
# 1           1  Capital O 88089 Hotel Elite
# 2           2         OYO 87715 Comfort In
# 3           3         OYO 87875 Krazy Home
# 4           4        OYO 22355 Hotel Istay
#
#                                       Cost Per Night  \
# 0  ₹500₹196374% offper room per nightView Details...
# 1  ₹549₹254778% offper room per nightView Details...
# 2  ₹541₹202573% offper room per nightView Details...
# 3  ₹500₹192574% offper room per nightView Details...
# 4  ₹699₹237170% offper room per nightView Details...
#
#                         Rating  \
# 0    4.5 (6 Ratings)·Excellent
# 1   4.5 (74 Ratings)·Excellent
# 2  4.6 (136 Ratings)·Excellent
# 3   4.5 (15 Ratings)·Excellent
# 4  4.6 (176 Ratings)·Excellent
#
#                                             Features  \
# 0        Hair Dryer  Reception  Free Wifi  + 15 more
# 1   Parking Facility  Reception  Free Wifi  + 14 ...
# ...

# %%
for x in d1['Features']:
    print(x)
# Out:
#  Hair Dryer  Reception  Free Wifi  + 15 more
#  Parking Facility  Reception  Free Wifi  + 14 more
#  Elevator  Free Wifi  Geyser  + 7 more
#  Elevator  Free Wifi  Geyser  + 6 more
#  Reception  Free Wifi  Power backup  + 13 more
#  Reception  Free Wifi  Power backup  + 7 more
#  Parking Facility  Reception  Daily Housekeeping  + 7 more
#  Reception  Free Wifi  Caretaker  + 11 more
#  Free Wifi  Power backup  AC  + 8 more
#  Free Wifi  Geyser  CCTV Cameras  + 5 more
#  Reception  Free Wifi  Power backup  + 16 more
#  Doctor on Call  Reception  AC  + 8 more
#  Doctor on Call  Parking Facility  Reception  + 18 more
#  Reception  Power backup  Security  + 11 more
#  TV
#  Parking Facility  Reception  Free Wifi  + 10 more
#  Elevator  Free Wifi  Geyser  + 7 more
#  Reception  CCTV Cameras  Power backup  + 3 more
#  Reception  Free Wifi  Power backup  + 10 more
#  Reception  Free Wifi  Power backup  + 13 more
#  Hair Dryer  AC  TV  + 3 more
# ...

# %%
d1['Features'].describe()
# Out:
# count                                        180
# unique                                       141
# top        Elevator  Free Wifi  Geyser  + 7 more
# freq                                           6
# Name: Features, dtype: object

# %%
d1['Features'].unique()
# Out:
# array([' Hair Dryer  Reception  Free Wifi  + 15 more',
#        ' Parking Facility  Reception  Free Wifi  + 14 more',
#        ' Elevator  Free Wifi  Geyser  + 7 more',
#        ' Elevator  Free Wifi  Geyser  + 6 more',
#        ' Reception  Free Wifi  Power backup  + 13 more',
#        ' Reception  Free Wifi  Power backup  + 7 more',
#        ' Parking Facility  Reception  Daily Housekeeping  + 7 more',
#        ' Reception  Free Wifi  Caretaker  + 11 more',
#        ' Free Wifi  Power backup  AC  + 8 more',
#        ' Free Wifi  Geyser  CCTV Cameras  + 5 more',
#        ' Reception  Free Wifi  Power backup  + 16 more',
#        ' Doctor on Call  Reception  AC  + 8 more',
#        ' Doctor on Call  Parking Facility  Reception  + 18 more',
#        ' Reception  Power backup  Security  + 11 more', ' TV ',
#        ' Parking Facility  Reception  Free Wifi  + 10 more',
#        ' Reception  CCTV Cameras  Power backup  + 3 more',
# ...

# %%
d1['wifi_availabilty'] = d1['Features'].apply(lambda x: 'yes' if 'Free Wifi' in x else 'no')

# %%
d1.head()
# Out:
#    Unnamed: 0                   Hotel Name  \
# 0           0            OYO 28715 Acclaim
# 1           1  Capital O 88089 Hotel Elite
# 2           2         OYO 87715 Comfort In
# 3           3         OYO 87875 Krazy Home
# 4           4        OYO 22355 Hotel Istay
#
#                                       Cost Per Night  \
# 0  ₹500₹196374% offper room per nightView Details...
# 1  ₹549₹254778% offper room per nightView Details...
# 2  ₹541₹202573% offper room per nightView Details...
# 3  ₹500₹192574% offper room per nightView Details...
# 4  ₹699₹237170% offper room per nightView Details...
#
#                         Rating  \
# 0    4.5 (6 Ratings)·Excellent
# 1   4.5 (74 Ratings)·Excellent
# 2  4.6 (136 Ratings)·Excellent
# 3   4.5 (15 Ratings)·Excellent
# 4  4.6 (176 Ratings)·Excellent
#
#                                             Features  \
# 0        Hair Dryer  Reception  Free Wifi  + 15 more
# 1   Parking Facility  Reception  Free Wifi  + 14 ...
# ...

# %%
d1['Hotel Name']
# Out:
# 0                       OYO 28715 Acclaim
# 1             Capital O 88089 Hotel Elite
# 2                    OYO 87715 Comfort In
# 3                    OYO 87875 Krazy Home
# 4                   OYO 22355 Hotel Istay
#                       ...
# 175           OYO 27979 Krishna Residency
# 176                 OYO 85494 Osho Palace
# 177    Collection O 9266 Hotel Kapoor Inn
# 178          OYO 22354 PG Hospitality Inn
# 179      Collection O 85116 peaceful stay
# Name: Hotel Name, Length: 180, dtype: object

# %%
d1['Hotel Name'][0]
# Out:
# 'OYO 28715 Acclaim'

# %%
for x in d1['Hotel Name']:
    print(x)
# Out:
# OYO 28715 Acclaim
# Capital O 88089 Hotel Elite
# OYO 87715 Comfort In
# OYO 87875 Krazy Home
# OYO 22355 Hotel Istay
# OYO 70216 Bluemoon Inn
# OYO 70893 Kl Khari Inn
# OYO 86940 Sunrise Villa
# OYO 13277 Hotel Neelam Palace
# OYO 87920 Hotel Happy Stay Inn
# OYO 84391 Townhouse Hotel Grand
# OYO 77554 Red Carmine Deluxe
# Capital O 87150 The imperial orbit
# Collection O 83904 Hotel Small Town
# OYO 75351 Hotel Moon Palace Dx
# SPOT ON 72997 D C Palace
# OYO 87588 Dolphin
# SPOT ON 29024 Jageer Palace
# OYO 86628 Ojas Palace
# OYO 44260 Saffron Inn
# OYO 84351 Welcome Palace
# SPOT ON 83214 Raj Guest House
# Townhouse 483 Hotel Rivasa Regency
# Collection O 76614 J K Hotel
# OYO 86920 Bella House
# Collection O 81401 Sai Residency
# OYO 61891 Hotel Kabila
# Collection O 83921 The Maharaja Grand
# SPOT ON 76979 Chandu Inn
# OYO 87205 Hotel Sapan Plaza
# Collection O 83547 Iconic Residency
# Capital O 86072 Holiday Home
# Collection O 50329 Singh Guest House
# ...

# %%
re.findall(r"\d+",d1['Hotel Name'][0])
# Out:
# ['28715']

# %%
HotelName=[]
for i in d1['Hotel Name']:
    HotelName.append(' '.join(i.split()[1:]))

# %%
HotelName
# Out:
# ['28715 Acclaim',
#  'O 88089 Hotel Elite',
#  '87715 Comfort In',
#  '87875 Krazy Home',
#  '22355 Hotel Istay',
#  '70216 Bluemoon Inn',
#  '70893 Kl Khari Inn',
#  '86940 Sunrise Villa',
#  '13277 Hotel Neelam Palace',
#  '87920 Hotel Happy Stay Inn',
#  '84391 Townhouse Hotel Grand',
#  '77554 Red Carmine Deluxe',
#  'O 87150 The imperial orbit',
#  'O 83904 Hotel Small Town',
#  '75351 Hotel Moon Palace Dx',
#  'ON 72997 D C Palace',
#  '87588 Dolphin',
#  'ON 29024 Jageer Palace',
#  '86628 Ojas Palace',
#  '44260 Saffron Inn',
#  '84351 Welcome Palace',
#  'ON 83214 Raj Guest House',
#  '483 Hotel Rivasa Regency',
#  'O 76614 J K Hotel',
#  '86920 Bella House',
#  'O 81401 Sai Residency',
#  '61891 Hotel Kabila',
#  'O 83921 The Maharaja Grand',
#  'ON 76979 Chandu Inn',
#  '87205 Hotel Sapan Plaza',
#  'O 83547 Iconic Residency',
#  'O 86072 Holiday Home',
#  'O 50329 Singh Guest House',
#  '62660 Hotel Park View',
#  '37773 Hotel J Joy',
#  '7217 Hotel Knk International',
# ...

# %%
d1['Hotel_Name']= HotelName

# %%
d1.head()
# Out:
#    Unnamed: 0                   Hotel Name  \
# 0           0            OYO 28715 Acclaim
# 1           1  Capital O 88089 Hotel Elite
# 2           2         OYO 87715 Comfort In
# 3           3         OYO 87875 Krazy Home
# 4           4        OYO 22355 Hotel Istay
#
#                                       Cost Per Night  \
# 0  ₹500₹196374% offper room per nightView Details...
# 1  ₹549₹254778% offper room per nightView Details...
# 2  ₹541₹202573% offper room per nightView Details...
# 3  ₹500₹192574% offper room per nightView Details...
# 4  ₹699₹237170% offper room per nightView Details...
#
#                         Rating  \
# 0    4.5 (6 Ratings)·Excellent
# 1   4.5 (74 Ratings)·Excellent
# 2  4.6 (136 Ratings)·Excellent
# 3   4.5 (15 Ratings)·Excellent
# 4  4.6 (176 Ratings)·Excellent
#
#                                             Features  \
# 0        Hair Dryer  Reception  Free Wifi  + 15 more
# 1   Parking Facility  Reception  Free Wifi  + 14 ...
# ...

# %%
d1['Features'].unique()
# Out:
# array([' Hair Dryer  Reception  Free Wifi  + 15 more',
#        ' Parking Facility  Reception  Free Wifi  + 14 more',
#        ' Elevator  Free Wifi  Geyser  + 7 more',
#        ' Elevator  Free Wifi  Geyser  + 6 more',
#        ' Reception  Free Wifi  Power backup  + 13 more',
#        ' Reception  Free Wifi  Power backup  + 7 more',
#        ' Parking Facility  Reception  Daily Housekeeping  + 7 more',
#        ' Reception  Free Wifi  Caretaker  + 11 more',
#        ' Free Wifi  Power backup  AC  + 8 more',
#        ' Free Wifi  Geyser  CCTV Cameras  + 5 more',
#        ' Reception  Free Wifi  Power backup  + 16 more',
#        ' Doctor on Call  Reception  AC  + 8 more',
#        ' Doctor on Call  Parking Facility  Reception  + 18 more',
#        ' Reception  Power backup  Security  + 11 more', ' TV ',
#        ' Parking Facility  Reception  Free Wifi  + 10 more',
#        ' Reception  CCTV Cameras  Power backup  + 3 more',
# ...

# %%
d1['Elevator'] = d1['Features'].apply(lambda x: 'yes' if 'Free Wifi' in x else 'no')

# %%
d1
# Out:
#      Unnamed: 0                          Hotel Name  \
# 0             0                   OYO 28715 Acclaim
# 1             1         Capital O 88089 Hotel Elite
# 2             2                OYO 87715 Comfort In
# 3             3                OYO 87875 Krazy Home
# 4             4               OYO 22355 Hotel Istay
# ..          ...                                 ...
# 175         175         OYO 27979 Krishna Residency
# 176         176               OYO 85494 Osho Palace
# 177         177  Collection O 9266 Hotel Kapoor Inn
# 178         178        OYO 22354 PG Hospitality Inn
# 179         179    Collection O 85116 peaceful stay
#
#                                         Cost Per Night  \
# 0    ₹500₹196374% offper room per nightView Details...
# 1    ₹549₹254778% offper room per nightView Details...
# 2    ₹541₹202573% offper room per nightView Details...
# 3    ₹500₹192574% offper room per nightView Details...
# 4    ₹699₹237170% offper room per nightView Details...
# ...

# %%
d1['Features'].unique()
# Out:
# array([' Hair Dryer  Reception  Free Wifi  + 15 more',
#        ' Parking Facility  Reception  Free Wifi  + 14 more',
#        ' Elevator  Free Wifi  Geyser  + 7 more',
#        ' Elevator  Free Wifi  Geyser  + 6 more',
#        ' Reception  Free Wifi  Power backup  + 13 more',
#        ' Reception  Free Wifi  Power backup  + 7 more',
#        ' Parking Facility  Reception  Daily Housekeeping  + 7 more',
#        ' Reception  Free Wifi  Caretaker  + 11 more',
#        ' Free Wifi  Power backup  AC  + 8 more',
#        ' Free Wifi  Geyser  CCTV Cameras  + 5 more',
#        ' Reception  Free Wifi  Power backup  + 16 more',
#        ' Doctor on Call  Reception  AC  + 8 more',
#        ' Doctor on Call  Parking Facility  Reception  + 18 more',
#        ' Reception  Power backup  Security  + 11 more', ' TV ',
#        ' Parking Facility  Reception  Free Wifi  + 10 more',
#        ' Reception  CCTV Cameras  Power backup  + 3 more',
# ...

# %%
d1['Parking Facility'] = d1['Features'].apply(lambda x: 'yes' if 'Free Wifi' in x else 'no')

# %%
d1['Power backup'] = d1['Features'].apply(lambda x: 'yes' if 'Free Wifi' in x else 'no')

# %%
d1['Doctor on Call'] = d1['Features'].apply(lambda x: 'yes' if 'Free Wifi' in x else 'no')

# %%
d1['CCTV Cameras'] = d1['Features'].apply(lambda x: 'yes' if 'Free Wifi' in x else 'no')

# %%
d1['Reception'] = d1['Features'].apply(lambda x: 'yes' if 'Free Wifi' in x else 'no')

# %%
d1['AC'] = d1['Features'].apply(lambda x: 'yes' if 'Free Wifi' in x else 'no')

# %%
d1.head()
# Out:
#    Unnamed: 0                   Hotel Name  \
# 0           0            OYO 28715 Acclaim
# 1           1  Capital O 88089 Hotel Elite
# 2           2         OYO 87715 Comfort In
# 3           3         OYO 87875 Krazy Home
# 4           4        OYO 22355 Hotel Istay
#
#                                       Cost Per Night  \
# 0  ₹500₹196374% offper room per nightView Details...
# 1  ₹549₹254778% offper room per nightView Details...
# 2  ₹541₹202573% offper room per nightView Details...
# 3  ₹500₹192574% offper room per nightView Details...
# 4  ₹699₹237170% offper room per nightView Details...
#
#                         Rating  \
# 0    4.5 (6 Ratings)·Excellent
# 1   4.5 (74 Ratings)·Excellent
# 2  4.6 (136 Ratings)·Excellent
# 3   4.5 (15 Ratings)·Excellent
# 4  4.6 (176 Ratings)·Excellent
#
#                                             Features  \
# 0        Hair Dryer  Reception  Free Wifi  + 15 more
# 1   Parking Facility  Reception  Free Wifi  + 14 ...
# ...

# %%
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        180 non-null    int64
#  1   Hotel Name        180 non-null    object
#  2   Cost Per Night    180 non-null    object
#  3   Rating            180 non-null    object
#  4   Features          180 non-null    object
#  5   Location          180 non-null    object
#  6   Selling_Price     180 non-null    float64
#  7   Cost_Price        180 non-null    float64
#  8   Discount          180 non-null    float64
#  9   City              180 non-null    object
#  10  Locality          180 non-null    object
#  11  Rate              173 non-null    object
#  12  Customer_Rating   173 non-null    object
#  13  Remarks           173 non-null    object
#  14  Category          177 non-null    object
#  15  wifi_availabilty  180 non-null    object
# ...

# %%
d1.to_csv('D:\oyo_delhi.csv')

# %%
d1.to_excel('D:\oyo_delhi.xlsx')

# %%
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        180 non-null    int64
#  1   Hotel Name        180 non-null    object
#  2   Cost Per Night    180 non-null    object
#  3   Rating            180 non-null    object
#  4   Features          180 non-null    object
#  5   Location          180 non-null    object
#  6   Selling_Price     180 non-null    float64
#  7   Cost_Price        180 non-null    float64
#  8   Discount          180 non-null    float64
#  9   City              180 non-null    object
#  10  Locality          180 non-null    object
#  11  Rate              173 non-null    object
#  12  Customer_Rating   173 non-null    object
#  13  Remarks           173 non-null    object
#  14  Category          177 non-null    object
#  15  wifi_availabilty  180 non-null    object
# ...
